# %%
import pandas as pd 
from ydata_profiling import ProfileReport

# %%
df = pd.read_csv('train.csv')

# %%
prof = ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# 100%|██████████| 12/12 [00:00<00:00, 62.38it/s]0<00:00, 19.72it/s, Describe variable: Embarked]
# Summarize dataset: 100%|██████████| 47/47 [00:09<00:00,  4.71it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:16<00:00, 16.50s/it]
# Render HTML: 100%|██████████| 1/1 [00:01<00:00,  2.00s/it]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 18.68it/s]
