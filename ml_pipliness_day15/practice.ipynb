# %%
import numpy as np
import pandas as pd

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder ,OrdinalEncoder 
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline,make_pipeline
from sklearn.feature_selection import SelectKBest,chi2
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv('used_cars_data.csv',usecols=['Name','Location','Owner_Type','Fuel_Type','Transmission','Price','Kilometers_Driven'])

df
# Out:
#                                                    Name    Location  \
# 0                                Maruti Wagon R LXI CNG      Mumbai
# 1                      Hyundai Creta 1.6 CRDi SX Option        Pune
# 2                                          Honda Jazz V     Chennai
# 3                                     Maruti Ertiga VDI     Chennai
# 4                       Audi A4 New 2.0 TDI Multitronic  Coimbatore
# ...                                                 ...         ...
# 7248                  Volkswagen Vento Diesel Trendline   Hyderabad
# 7249                             Volkswagen Polo GT TSI      Mumbai
# 7250                             Nissan Micra Diesel XV     Kolkata
# 7251                             Volkswagen Polo GT TSI        Pune
# 7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Price
# 0                 72000       CNG       Manual      First   1.75
# 1                 41000    Diesel       Manual      First  12.50
# 2                 46000    Petrol       Manual      First   4.50
# 3                 87000    Diesel       Manual      First   6.00
# 4                 40670    Diesel    Automatic     Second  17.74
# ...                 ...       ...          ...        ...    ...
# 7248              89411    Diesel       Manual      First    NaN
# 7249              59000    Petrol    Automatic      First    NaN
# 7250              28000    Diesel       Manual      First    NaN
# 7251              52262    Petrol    Automatic      Third    NaN
# 7252              72443    Diesel    Automatic      First    NaN
#
# [7253 rows x 7 columns]

# %%
#Train the data 
x_train , x_test , y_train , y_test = train_test_split(df.drop('Transmission',axis=1),
                                                       df['Transmission'],
                                                       test_size=0.3,
                                                       random_state=0)
x_train
# Out:
#                                        Name   Location  Kilometers_Driven  \
# 6811               Honda City i VTEC CVT VX  Hyderabad              39822
# 5029   Ford Figo Aspire 1.2 Ti-VCT Ambiente    Chennai              29875
# 2423                      BMW 3 Series 320d     Mumbai              25000
# 2434       Hyundai Xcent 1.2 Kappa S Option    Kolkata              42000
# 2559                       Maruti Swift VDI    Chennai              78000
# ...                                     ...        ...                ...
# 4931                    Mahindra TUV 300 T8       Pune              67000
# 3264  Toyota Innova 2.5 G (Diesel) 8 Seater     Jaipur             147350
# 1653                   Mahindra Scorpio VLX    Kolkata              62000
# 2607       Hyundai Verna CRDi 1.6 SX Option       Pune              50000
# 2732                 Maruti Swift Dzire ZDI     Jaipur              83000
#
#      Fuel_Type Owner_Type  Price
# 6811    Petrol      First    NaN
# 5029    Petrol      First   4.85
# 2423    Diesel      First  17.99
# 2434    Petrol      First   3.45
# 2559    Diesel      First   4.40
# ...        ...        ...    ...
# 4931    Diesel      First   6.30
# 3264    Diesel     Second   4.95
# 1653    Diesel      First   6.25
# 2607    Diesel      First  11.50
# 2732    Diesel      First   4.30
#
# [5077 rows x 6 columns]

# %%
#Data Clening / imputation transformer
trf1 = ColumnTransformer([
    ('impute_price',SimpleImputer(),[5])
],remainder='passthrough')

# %% [markdown]
# ### handle_unknown= 'ignore' means if you train your data like that
# City: Delhi, Mumbai, Pune
#
# #### Encoder learns
# ##### ['Delhi', 'Mumbai', 'Pune']
# ##### Test Real world Data
# ##### City: Delhi, Chennai
# ##### if u don't use it it throw error if you give different values like 'chennai' ValueError: Found unknown categories ['Chennai']
# ##### OneHotEncoder(handle_unknown='ignore') if unseen category appers Chennai → [0, 0, 0]

# %%
#Encoding Phase 
trf2 = ColumnTransformer([
    ('ohe_loc_ftype',OneHotEncoder(sparse_output=False,handle_unknown='ignore'),[1,3])
],remainder='passthrough')

# %%
# Scaling Phase
trf3 = ColumnTransformer([
    ('Scale_kilometer',MinMaxScaler(),[2])
])

# %%
trf5 = DecisionTreeClassifier()

# %% [markdown]
# # Create Pipeline

# %%
pipe = Pipeline([
    ('trf1',trf1),
    ('trf2',trf2),
    ('trf3',trf3),
    ('trf5',trf5)
])
pipe.named_steps
# Out:
# {'trf1': ColumnTransformer(remainder='passthrough',
#                    transformers=[('impute_price', SimpleImputer(), [5])]),
#  'trf2': ColumnTransformer(remainder='passthrough',
#                    transformers=[('ohe_loc_ftype',
#                                   OneHotEncoder(handle_unknown='ignore',
#                                                 sparse_output=False),
#                                   [1, 3])]),
#  'trf3': ColumnTransformer(transformers=[('Scale_kilometer', MinMaxScaler(), [2])]),
#  'trf5': DecisionTreeClassifier()}

# %%
# pipe = make_pipeline(trf1,trf2,trf3,trf5)
# x_train
pipe.named_steps
# Out:
# {'trf1': ColumnTransformer(remainder='passthrough',
#                    transformers=[('impute_price', SimpleImputer(), [5])]),
#  'trf2': ColumnTransformer(remainder='passthrough',
#                    transformers=[('ohe_loc_ftype',
#                                   OneHotEncoder(handle_unknown='ignore',
#                                                 sparse_output=False),
#                                   [1, 3])]),
#  'trf3': ColumnTransformer(transformers=[('Scale_kilometer', MinMaxScaler(), [2])]),
#  'trf5': DecisionTreeClassifier()}

# %%
# train
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('trf1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('impute_price',
#                                                   SimpleImputer(), [5])])),
#                 ('trf2',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe_loc_ftype',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   [1, 3])])),
#                 ('trf3',
#                  ColumnTransformer(transformers=[('Scale_kilometer',
#                                                   MinMaxScaler(), [2])])),
#                 ('trf5', DecisionTreeClassifier())])

# %%
# Code here
pipe.named_steps
# Out:
# {'trf1': ColumnTransformer(remainder='passthrough',
#                    transformers=[('impute_price', SimpleImputer(), [5])]),
#  'trf2': ColumnTransformer(remainder='passthrough',
#                    transformers=[('ohe_loc_ftype',
#                                   OneHotEncoder(handle_unknown='ignore',
#                                                 sparse_output=False),
#                                   [1, 3])]),
#  'trf3': ColumnTransformer(transformers=[('Scale_kilometer', MinMaxScaler(), [2])]),
#  'trf5': DecisionTreeClassifier()}

# %%
#predict
y_pred = pipe.predict(x_test)

# %%
y_pred
# Out:
# array(['Manual', 'Manual', 'Manual', ..., 'Manual', 'Manual', 'Manual'],
#       shape=(2176,), dtype=object)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.7316176470588235

# %%
# cross validation using cross_val_score
from sklearn.model_selection import cross_val_score
cross_val_score(pipe, x_train, y_train, cv=5, scoring='accuracy').mean()
# Out:
# np.float64(0.7120348318529149)

# %%
# gridsearchcv
params = {
    'trf5__max_depth':[1,2,3,4,5,None]
}

# %%
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(pipe, params, cv=5, scoring='accuracy')
grid.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('trf1',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('impute_price',
#                                                                          SimpleImputer(),
#                                                                          [5])])),
#                                        ('trf2',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ohe_loc_ftype',
#                                                                          OneHotEncoder(handle_unknown='ignore',
#                                                                                        sparse_output=False),
#                                                                          [1,
#                                                                           3])])),
#                                        ('trf3',
#                                         ColumnTransformer(transformers=[('Scale_kilometer',
#                                                                          MinMaxScaler(),
#                                                                          [2])])),
#                                        ('trf5', DecisionTreeClassifier())]),
#              param_grid={'trf5__max_depth': [1, 2, 3, 4, 5, None]},
#              scoring='accuracy')
